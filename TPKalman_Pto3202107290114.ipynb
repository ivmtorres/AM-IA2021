# %% [markdown]
# <a href="https://colab.research.google.com/github/ivmtorres/AM-IA2021/blob/main/TPKalman_Pto3202107290114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Importar archivos locales

# %%
#subimos el archivo de posicion
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9344c1d8-3273-4677-be95-f873333db103" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9344c1d8-3273-4677-be95-f873333db103">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving posicion.dat to posicion (1).dat
# {'posicion.dat': b'0.000000000000000000e+00 0.000000000000000000e+00 0.000000000000000000e+00\r\n-2.504231408238410950e+00 -1.569490623916499317e+01 3.945086878724396229e+01\r\n-1.010381195787340403e+01 -2.843151083309203386e+01 8.347097788378596306e+01\r\n-2.221278686635196209e+01 -3.864409956918098032e+01 1.317100292374379933e+02\r\n-3.824520135298371315e+01 -4.676695823553018272e+01 1.838177247922867537e+02\r\n-5.761510063614696264e+01 -5.323437262023799121e+01 2.394437664938159287e+02\r\n-7.973652993235737085e+01 -5.848062850954011083e+01 2.982378562875092030e+02\r\n-1.040235344637185335e+02 -6.294001169316470623e+01 3.598496961197815835e+02\r\n-1.298901594458147883e+02 -6.704680795711465180e+01 4.239289879351854324e+02\r\n-1.567504500979557633e+02 -7.123530308995395899e+01 4.901254336796700954e+02\r\n-1.840184516375884414e+02 -7.593978287884965539e+01 5.580887352996505797e+02\r\n-2.111082092840224504e+02 -8.159453311236575246e+01 6.274685947392135859e+02\r\n-2.374607113497331738e+02 -8.860857303300872445e+01 6.979294918817467988e+02\r\n-2.628872311124578118e+02 -9.704367807554081082e+01 7.693390031475573778e+02\r\n-2.874681627405807376e+02 -1.067092489795759320e+02 8.417123142820782959e+02\r\n-3.112899625701829791e+02 -1.174090015206020325e+02 9.150679360651411116e+02\r\n-3.344390869503840804e+02 -1.289466514780651778e+02 9.894243792723864317e+02\r\n-3.570019922219216824e+02 -1.411259146262891591e+02 1.064800154683180153e+03\r\n-3.790651347339153290e+02 -1.537505067444872111e+02 1.141213773073628545e+03\r\n-4.007149708261713386e+02 -1.666241436090786010e+02 1.218683745222631842e+03\r\n-4.220379568422213197e+02 -1.795505409964825958e+02 1.297228581908624619e+03\r\n-4.431205491302534938e+02 -1.923334146854467690e+02 1.376866793906781822e+03\r\n-4.640492040300741792e+02 -2.047764804512262344e+02 1.457616891997400671e+03\r\n-4.849103778880089521e+02 -2.166834540725685656e+02 1.539497386956121773e+03\r\n-5.057905270466580987e+02 -2.278580513249617070e+02 1.622526789562311023e+03\r\n-5.267761078532785177e+02 -2.381039879873860627e+02 1.706723610592074692e+03\r\n-5.479535189568996429e+02 -2.472251085652969778e+02 1.792106315508019179e+03\r\n-5.693785138763487339e+02 -2.550936402531806380e+02 1.878669296810403466e+03\r\n-5.910258782124146819e+02 -2.617624849653802812e+02 1.966343343554064631e+03\r\n-6.128571797916665673e+02 -2.673140392617788166e+02 2.055048861702438444e+03\r\n-6.348339864360168576e+02 -2.718306997015606612e+02 2.144706257224082947e+03\r\n-6.569178659683093429e+02 -2.753948628446087241e+02 2.235235936082433909e+03\r\n-6.790703862132504582e+02 -2.780889252510387450e+02 2.326558304244652390e+03\r\n-7.012531149946153164e+02 -2.799952834800351411e+02 2.418593767675571144e+03\r\n-7.234276201315224171e+02 -2.811963340917136520e+02 2.511262732341885567e+03\r\n-7.455554694468155503e+02 -2.817744736447930336e+02 2.604485604209825397e+03\r\n-7.675982307698577642e+02 -2.818120987007860094e+02 2.698182789242360741e+03\r\n-7.895174719151109457e+02 -2.813916058172471821e+02 2.792274693409446627e+03\r\n-8.112747607119381428e+02 -2.805953915552236140e+02 2.886681722673587501e+03\r\n-8.328316649822518229e+02 -2.795058524743653834e+02 2.981324283002410084e+03\r\n-8.541497525470331311e+02 -2.782053851345553994e+02 3.076122780360747129e+03\r\n-8.751905912300571799e+02 -2.767763860940467566e+02 3.170997620714828372e+03\r\n-8.959157488541677594e+02 -2.753012519136536866e+02 3.265869210031349212e+03\r\n-9.162867932468652725e+02 -2.738623791541904211e+02 3.360657954273279756e+03\r\n-9.362652922226116061e+02 -2.725421643729787320e+02 3.455284259409643710e+03\r\n-9.558128136107698083e+02 -2.714230041310656816e+02 3.549668531404808164e+03\r\n-9.748909252323210239e+02 -2.705872949881013483e+02 3.643731176225002855e+03\r\n-9.934611949110403657e+02 -2.701174335032701492e+02 3.737392599835060537e+03\r\n-1.011485190467908978e+03 -2.700958162371534854e+02 3.830573208202142268e+03\r\n-1.028924479729495943e+03 -2.706048397489357740e+02 3.923193407 ...

# %%
#subimos el archivo de velocidad
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cd76cc91-14ea-415d-a3e5-d19a509b15d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd76cc91-14ea-415d-a3e5-d19a509b15d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving velocidad.dat to velocidad (1).dat
# {'velocidad.dat': b'2.387614226900041103e-01 -1.731881899095606059e+01 3.704948261368554085e+01\r\n-5.149565109074046632e+00 -1.414337445181723751e+01 4.179387195119875287e+01\r\n-9.951936859260968049e+00 -1.140221570047674504e+01 4.618796323431979545e+01\r\n-1.416835382795579790e+01 -9.095342736774000514e+00 5.023175646294748731e+01\r\n-1.779881601496163057e+01 -7.222755560768746363e+00 5.392525163710888592e+01\r\n-2.084332342044581310e+01 -5.784454172502591973e+00 5.726844875679307734e+01\r\n-2.330187604422826553e+01 -4.780438571917329682e+00 6.026134782208464458e+01\r\n-2.517447388650180073e+01 -4.210708759001136059e+00 6.290394883285262040e+01\r\n-2.646111694720457308e+01 -4.075264733841322595e+00 6.519625178920978215e+01\r\n-2.716180522622016724e+01 -4.374106496354215778e+00 6.713825669106881833e+01\r\n-2.727653872374503408e+01 -5.107234046590747312e+00 6.872996353846974671e+01\r\n-2.680531743963365443e+01 -6.274647384496347513e+00 6.997137233144167112e+01\r\n-2.587813261530851605e+01 -7.754444038159178376e+00 7.093378158964411284e+01\r\n-2.498931630434481121e+01 -9.083052010415769928e+00 7.188832607054490609e+01\r\n-2.418695633750030538e+01 -1.021537575980926249e+01 7.286138132912878973e+01\r\n-2.347105271471536980e+01 -1.115141528629578715e+01 7.385294736540345184e+01\r\n-2.284160543593407056e+01 -1.189117058989040743e+01 7.486302417939714360e+01\r\n-2.229861450124008115e+01 -1.243464167060665204e+01 7.589161177106734613e+01\r\n-2.184207991058065090e+01 -1.278182852840200212e+01 7.693871014045726042e+01\r\n-2.147200166398033616e+01 -1.293273116331965866e+01 7.800431928753641841e+01\r\n-2.118837976143913693e+01 -1.288734957535962167e+01 7.908843921229163243e+01\r\n-2.099121420296069118e+01 -1.264568376449278730e+01 8.019106991478292912e+01\r\n-2.088050498848315328e+01 -1.220773373073279799e+01 8.131221139494846284e+01\r\n-2.085625211810111068e+01 -1.157349947409784363e+01 8.245186365281915641e+01\r\n-2.091845559178182157e+01 -1.074298099456063937e+01 8.361002668837318197e+01\r\n-2.106711540948163019e+01 -9.716178292106633307e+00 8.478670050165237626e+01\r\n-2.130099948189410242e+01 -8.495840695726561975e+00 8.598091723828972022e+01\r\n-2.154258498985763026e+01 -7.254955440136168221e+00 8.713177969553308344e+01\r\n-2.174573832083819980e+01 -6.096466744260510495e+00 8.820304811859907090e+01\r\n-2.191045947480688483e+01 -5.020374608074178013e+00 8.919472250748759734e+01\r\n-2.203674845182172248e+01 -4.026679031580783885e+00 9.010680286217325374e+01\r\n-2.212460525180995319e+01 -3.115380014776633288e+00 9.093928918268511552e+01\r\n-2.217402987480090815e+01 -2.286477557669172711e+00 9.169218146899413568e+01\r\n-2.218502232080754766e+01 -1.539971660272385634e+00 9.236547972111520721e+01\r\n-2.215758258984806162e+01 -8.758623225510291377e-01 9.295918393905458288e+01\r\n-2.209171068187424680e+01 -2.941495445327291236e-01 9.347329412279873395e+01\r\n-2.198740659691975452e+01 2.051666737811501662e-01 9.390781027235470901e+01\r\n-2.184467033496548538e+01 6.220863324065248889e-01 9.426273238772228069e+01\r\n-2.166350189598779252e+01 9.566094313408939342e-01 9.453806046890076686e+01\r\n-2.144390128005397855e+01 1.208735970586985786e+00 9.473379451591335965e+01\r\n-2.118586848712220672e+01 1.378465950115241867e+00 9.484993452870185138e+01\r\n-2.088940351722158084e+01 1.465799369962041965e+00 9.488648050731626427e+01\r\n-2.055450637029571226e+01 1.470736230110560427e+00 9.484343245174204640e+01\r\n-2.018117704640826560e+01 1.393276530554430792e+00 9.472079036197010282e+01\r\n-1.976941554548102431e+01 1.233420271319118910e+00 9.451855423801407596e+01\r\n-1.931922186760857585e+01 9.911674523782494362e-01 9.423672407988124178e+01\r\n-1.883059601272179862e+01 6.665180737418268109e-01 9.387529988754795340e+01\r\n-1.830353798084979644e+01 2.594721354162174975e-01 9.343428166103149124e+01\r\n-1.773804777197074145e+01 -2.299703626085829455e-01 9.291366940031912236e+01\r\n-1.713412538609554758e+01 -8.018094203289365396e-01 9.231346310543267464e ...

# %%
#subimos el archivo de aceleracion
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3dc75c5b-c30d-47c7-9fb4-c838be32b381" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3dc75c5b-c30d-47c7-9fb4-c838be32b381">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aceleracion.dat to aceleracion (1).dat
# {'aceleracion.dat': b'-5.681303922581719235e+00 3.392587432921573054e+00 4.919538364774780348e+00\r\n-5.095349141004589910e+00 2.958301645239657773e+00 4.569240310317127296e+00\r\n-4.509394359383804840e+00 2.524015857543190577e+00 4.218942255855836265e+00\r\n-3.923439577798490063e+00 2.089730069832512527e+00 3.868644201398637961e+00\r\n-3.337484796222270234e+00 1.655444282146618207e+00 3.518346146944168140e+00\r\n-2.751530014618765563e+00 1.221158494445262477e+00 3.168048092488788825e+00\r\n-2.165575233077106532e+00 7.868727067316285684e-01 2.817750038015219616e+00\r\n-1.579620451477239840e+00 3.525869190334560699e-01 2.467451983563478279e+00\r\n-9.936656698737351689e-01 -8.169886866744491272e-02 2.117153929104460985e+00\r\n-4.077108882847824134e-01 -5.159846563683458953e-01 1.766855874647262681e+00\r\n1.782438933041703422e-01 -9.502704440692468779e-01 1.416557820186426397e+00\r\n7.641986748894851189e-01 -1.384556231767419376e+00 1.066259765731956577e+00\r\n9.320444829285747801e-01 -1.426750083719042550e+00 9.452890920410652598e-01\r\n8.455881388861143932e-01 -1.230465860827735014e+00 9.637998697387502034e-01\r\n7.591317948345022160e-01 -1.034181637932761078e+00 9.823106474383394016e-01\r\n6.726754507867553912e-01 -8.378974150386966357e-01 1.000821425136905418e+00\r\n5.862191067299136193e-01 -6.416131921528176463e-01 1.019332202831037648e+00\r\n4.997627626753455843e-01 -4.453289692598900729e-01 1.037842980530058412e+00\r\n4.133064186253250227e-01 -2.490447463651435100e-01 1.056353758229079176e+00\r\n3.268500745725759771e-01 -5.276052347289805766e-02 1.074864535925371456e+00\r\n2.403937305234649102e-01 1.435236994186652737e-01 1.093375313622800604e+00\r\n1.539373864707158646e-01 3.398079223102286051e-01 1.111886091320684500e+00\r\n6.748104241796681890e-02 5.360921452024740574e-01 1.130396869019023143e+00\r\n-1.897530163478222676e-02 7.323763680938100151e-01 1.148907646715997544e+00\r\n-1.054316456848027883e-01 9.286605909865102149e-01 1.167418424415245681e+00\r\n-1.918879897402803181e-01 1.124944813878755667e+00 1.185929202110855840e+00\r\n-2.608015964567975686e-01 1.282083535428217402e+00 1.190659474350726832e+00\r\n-2.223694194684071590e-01 1.199686975732113581e+00 1.111065440161951301e+00\r\n-1.839372424763610070e-01 1.117290416036468059e+00 1.031471405974102140e+00\r\n-1.455050654872138693e-01 1.034893856341682294e+00 9.518773717843771465e-01\r\n-1.070728884942013792e-01 9.524972966455891310e-01 8.722833375965137748e-01\r\n-6.864071149948358652e-02 8.701007369504054623e-01 7.926893034072861610e-01\r\n-3.020853450846061605e-02 7.877041772556481192e-01 7.130952692186838249e-01\r\n8.223642485518212197e-03 7.053076175598107511e-01 6.335012350288593552e-01\r\n4.665581947529062745e-02 6.229110578643712870e-01 5.539072008411949355e-01\r\n8.508799646801890049e-02 5.405144981689886663e-01 4.743131666515978395e-01\r\n1.235201734596103051e-01 4.581179384733218285e-01 3.947191324629102382e-01\r\n1.619523504518838308e-01 3.757213787782234249e-01 3.151250982751889751e-01\r\n2.003845274414288724e-01 2.933248190819313095e-01 2.355310640853076620e-01\r\n2.388167044352940138e-01 2.109282593867192190e-01 1.559370298967905910e-01\r\n2.772488814257485501e-01 1.285316996908250076e-01 7.634299570793245948e-02\r\n3.156810584193863178e-01 4.613513999549923028e-02 -3.251038481266732560e-03\r\n3.541132354109777225e-01 -3.626141969971286017e-02 -8.284507266955642990e-02\r\n3.925454124027965008e-01 -1.186579793953796980e-01 -1.624391068583008746e-01\r\n4.309775893939331581e-01 -2.010545390910465358e-01 -2.420331410473863798e-01\r\n4.694097663868888048e-01 -2.834510987862586262e-01 -3.216271752362445113e-01\r\n5.078419433784802095e-01 -3.658476584818117772e-01 -4.012212094251026429e-01\r\n5.462741203696168668e-01 -4.482442181777059886e-01 -4.808152436139607744e-01\r\n5.847062973621177662e-01 -5.306407778726907054e-01 -5.604092778025915322e-01\r\n6.231384743546186655e-01 -6.130373375685849169e-01 -6.400033119912222901e-01\r\n6.615706513457553228e-01 -6.9 ...

# %%
#leemos el archivo de posicion
df_pos=pd.read_table(r'/content/posicion.dat',
names=['posX','posY','posZ'],sep=' ',encoding='utf-8')

# %%
#leemos el achivo de velocidad
df_vel=pd.read_table(r'/content/velocidad.dat',
names=['velX','velY','velZ'],sep=' ',encoding='utf-8')

# %%
#leemos el archivo de aceleracion
df_acel=pd.read_table(r'/content/aceleracion.dat',
names=['acelX','acelY','acelZ'],sep=' ',encoding='utf-8')

# %%
np_pos = df_pos.to_numpy()

# %%
np_vel = df_vel.to_numpy()

# %%
np_acel = df_acel.to_numpy()

# %%
#armo las matrizes de posicion - velocidad - aceleracion sin ruido
np_pos_matrix=np.asmatrix(np_pos)
np_vel_matrix=np.asmatrix(np_vel)
np_acel_matrix=np.asmatrix(np_acel)
#defino la media y varianza del ruido
mu = 0 ; sigma = 10
#armo las matrizes de posicion - velocidad - aceleracion con ruido gaussiano ----> No lo utilizo
np_pos_matrix_noise_normal = np_pos_matrix + np.random.normal(mu, sigma, np_pos_matrix.shape)  
np_vel_matrix_noise_normal = np_vel_matrix + np.random.normal(mu, sigma, np_vel_matrix.shape)
np_acel_matrix_noise_normal = np_acel_matrix + np.random.normal(mu, sigma, np_acel_matrix.shape)
#armo las matrizes de posicion - velocidad - aceleracion con ruido uniforme ----> No lo utilizo
np_pos_matrix_noise_uniform = np_pos_matrix + np.random.uniform(size = np_pos_matrix.shape, low = 0, high = 1) 
np_vel_matrix_noise_uniform = np_vel_matrix + np.random.uniform(size = np_vel_matrix.shape, low = 0, high = 1)
np_acel_matrix_noise_uniform = np_acel_matrix + np.random.uniform(size = np_acel_matrix.shape, low = 0, high = 1)

# %%
#creo la matriz de estados que es el data set sin ruido ---> lo voy a utilizar
x_estado_medidos = np.concatenate((np_pos_matrix,np_vel_matrix,np_acel_matrix),axis=1)

# %%
#data set con valores medidos sin ruido ---> si lo utilizo
x_estado_medidos.shape
# Out:
# (351, 9)

# %%
#creo la matriz de estados que es el data set con ruido normal ---> esto NO lo vamos a utilizar
x_estado_medidos_noise_normal = np.concatenate((np_pos_matrix_noise_normal,np_vel_matrix_noise_normal,np_acel_matrix_noise_normal),axis=1)

# %%
#data set con valores medidos con ruido ----> esto no lo utilizo
x_estado_medidos_noise_normal.shape
# Out:
# (351, 9)

# %%
#creo la matriz de estados que es el data set con ruido uniforme ---> esto NO lo vamos a utilizar
x_estado_medidos_noise_uniform = np.concatenate((np_pos_matrix_noise_uniform,np_vel_matrix_noise_uniform,np_acel_matrix_noise_uniform),axis=1)

# %%
x_estado_medidos_noise_uniform.shape
# Out:
# (351, 9)

# %%
#armo el vector de estado inicial
x_estado_estimado_inicial = np.array([10.7533,36.6777,-45.1769,1.1009,-17.0,35.7418,-5.7247,3.4268,5.2774])

# %%
#vector de estado estimado inicial
x_estado_estimado_inicial.shape
# Out:
# (9,)

# %%
p_covarianza_estimado_inicial_diagonal=np.array([100,100,100,1,1,1,0.01,0.01,0.01])
p_covarianza_estimado_inicial = np.diag(p_covarianza_estimado_inicial_diagonal)

# %%
#covarianza estimado inicial
p_covarianza_estimado_inicial.shape
# Out:
# (9, 9)

# %%
q_covarianza_ruido_planta_diagonal=np.array([0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3])
q_covarianza_ruido_planta = np.diag(q_covarianza_ruido_planta_diagonal)

# %%
#covarianza ruido de planta
q_covarianza_ruido_planta.shape
# Out:
# (9, 9)

# %%
# #Armamos la matriz R para el pto 1 y el pto 2
# epx=10; epy=10; epz=10 
# r_covarianza_medicion=np.array([epx**2,epy**2,epz**2])
# r_covarianza_ruido_medicion = np.diag(r_covarianza_medicion)
#Armamos la matriz R para el pto 3
epx=10; epy=10; epz=10; evx=0.2; evy=0.2; evz=0.2; 
r_covarianza_medicion=np.array([epx**2,epy**2,epz**2,evx**2,evy**2,evz**2])
r_covarianza_ruido_medicion = np.diag(r_covarianza_medicion)

# %%
r_covarianza_ruido_medicion.shape
# Out:
# (6, 6)

# %%
#tiempo - intervalo de muestreo ---> Para el TP se plantea 1 segundo.
h_tiempo_muestreo=1
#termino - primer derivada
h_intervalo_tiempo = h_tiempo_muestreo
#termino - segunda derivada
h_intervalo_tiempo2 = (0.5*(h_tiempo_muestreo**2))

# %%
#genero una matriz de identidad base de dimension 3x3
matriz_indentidad_dim3 = np.identity(3)
#genero una matriz nula base de dimension 3x3
matriz_zeros_dim3 = np.zeros((3,3))

# %%
#genero matriz de transicion
#armo la matriz por filas
#primero la fila posicion
f_matriz_transicion_fila_pos = np.concatenate((matriz_indentidad_dim3,h_intervalo_tiempo*matriz_indentidad_dim3,h_intervalo_tiempo2*matriz_indentidad_dim3),axis=1)
#segundo la fila velocidad
f_matriz_transicion_fila_vel = np.concatenate((matriz_zeros_dim3,matriz_indentidad_dim3,h_intervalo_tiempo*matriz_indentidad_dim3),axis=1)
#tercero la fila aceleracion
f_matriz_transicion_fila_acel = np.concatenate((matriz_zeros_dim3,matriz_zeros_dim3,h_intervalo_tiempo*matriz_indentidad_dim3),axis=1)
#armo la matriz de transicion completa 
f_matriz_transicion = np.concatenate((f_matriz_transicion_fila_pos,f_matriz_transicion_fila_vel,f_matriz_transicion_fila_acel),axis=0)

# %%
# #genero la matriz de observacion - medicion solo de posicion
# h_matriz_observacion = np.concatenate((matriz_indentidad_dim3,matriz_zeros_dim3,matriz_zeros_dim3), axis=1)
#genero la matriz de observacion - medicion de posicion y velocidad
h_matriz_observacion_fila_posicion = np.concatenate((matriz_indentidad_dim3,matriz_zeros_dim3,matriz_zeros_dim3), axis=1)
h_matriz_observacion_fila_velocidad = np.concatenate((matriz_zeros_dim3,matriz_indentidad_dim3,matriz_zeros_dim3), axis=1)
h_matriz_observacion = np.concatenate((h_matriz_observacion_fila_posicion,h_matriz_observacion_fila_velocidad), axis=0)

# %%
h_matriz_observacion.shape
# Out:
# (6, 9)

# %%
auxiliar =h_matriz_observacion.dot(np.transpose(x_estado_medidos[0,:]))
auxiliar_ruido=np.concatenate((np.random.normal(mu, sigma, size=(3,1)),np.random.normal(mu, 0.2, size=(3,1))),axis=0)
z_observaciones_noise=np.asmatrix(auxiliar + auxiliar_ruido)

# %%
#inicializo la matriz de mediciones afectada por el ruido gaussiano
auxiliar =h_matriz_observacion.dot(np.transpose(x_estado_medidos[0,:]))
auxiliar_ruido=np.concatenate((np.random.normal(mu, sigma, size=(3,1)),np.random.normal(mu, 0.2, size=(3,1))),axis=0)
z_observaciones_noise=np.asmatrix(auxiliar + auxiliar_ruido) 
print(z_observaciones_noise.shape)
contador = 1
#las observaciones son la matriz de estados con el ruido gaussiano para el punto 1
for x_estado in x_estado_medidos[1:,:]:
  contador = contador + 1
  auxiliar =h_matriz_observacion.dot(np.transpose(x_estado))
  auxiliar_ruido=np.concatenate((np.random.normal(mu, sigma, size=(3,1)),np.random.normal(mu, 0.2, size=(3,1))),axis=0)
  z_observaciones_noise_fila = np.asmatrix(auxiliar+auxiliar_ruido)
  z_observaciones_noise = np.concatenate((z_observaciones_noise,z_observaciones_noise_fila),axis=1)
#******************************************************************************************************************************
#*********************Para trabajar con ruido uniforme armamos la matriz de observacion sumandole ruido uniforme***************
#******************************************************************************************************************************
#inicializo la matriz de mediciones afectada por el ruido uniforme

# z_observaciones_noise = np.asmatrix(h_matriz_observacion.dot(np.transpose(x_estado_medidos[0,:]))+np.random.uniform(size = (3,1), low = 0, high = 10))  
# z_observaciones_noise.shape
# contador = 1
# #las observaciones son la matriz de estados con el ruido gaussiano para el punto 1
# for x_estado in x_estado_medidos[1:,:]:
#   contador = contador + 1
#   z_observaciones_noise_fila = np.asmatrix(h_matriz_observacion.dot(np.transpose(x_estado))+np.random.uniform(size = (3,1), low = -17.32, high = 17.32))
#   z_observaciones_noise = np.concatenate((z_observaciones_noise,z_observaciones_noise_fila),axis=1)
# Out:
# (6, 1)

# %%
contador
# Out:
# 351

# %%
z_observaciones_noise.shape
# Out:
# (6, 351)

# %%
z_observaciones_noise[:,0:3]
# Out:
# matrix([[ -1.16338698,   3.67600383, -27.86671478],
#         [ -2.55564671,  -6.64221787, -25.93757468],
#         [  1.25517394,  46.0570273 ,  92.2769209 ],
#         [  0.1660762 ,  -5.31984957,  -9.90837762],
#         [-17.69409885, -13.96537232, -11.08339014],
#         [ 36.78992229,  41.91535389,  46.03336168]])

# %%
#importo la libreria para invertir
from numpy.linalg import inv

# %%
xpriori = x_estado_estimado_inicial
ppriori = p_covarianza_estimado_inicial
contador = 0
mediciones = []
predicciones = []
estimaciones = []
kalmanValores = []
#armo la iteracion y la actualizacion del vector de estado y del ruido 
for z_medida_noise in np.transpose(z_observaciones_noise):
  #armo el lazo de iteracion
  contador = contador + 1
  #realizo la prediccion de x1/0 con el vector de estado incial
  x1brr0=f_matriz_transicion.dot(xpriori)
  #realizo la prediccion de p1/0 con la matriz de covarianza inicial
  p1brr0=f_matriz_transicion.dot(ppriori).dot(np.transpose(f_matriz_transicion))+q_covarianza_ruido_planta
  #realizo el calculo de S
  s1 = h_matriz_observacion.dot(p1brr0).dot(np.transpose(h_matriz_observacion))+r_covarianza_ruido_medicion
  #realizo el calculo de k
  k1= p1brr0.dot(np.transpose(h_matriz_observacion)).dot(inv(s1))

  #calculo delta medida de innovacion
  delta1 = np.asarray(z_medida_noise).flatten()-h_matriz_observacion.dot(x1brr0)
  #calculo la estimación de x y actualizo el valor de x
  x1brr1 = x1brr0 + k1.dot(delta1)
  # calculo la estimación de p y actualizo el valor de p
  p1brr1 = (np.identity(len(k1))-k1.dot(h_matriz_observacion)).dot(p1brr0)
  #cargo los datos para evaluacion posterior
  mediciones.append(np.asarray(z_medida_noise).flatten())
  predicciones.append(x1brr0)
  estimaciones.append(x1brr1)
  kalmanValores.append(k1)
  # #convierto el estado actual en el estado previo
  xpriori = x1brr1
  ppriori = p1brr1

# %%
#grafico sobre el eje x
t = np.arange(0, 351, h_tiempo_muestreo)
fig = plt.figure()
fig.suptitle('TP Kalman con 3 grados de libertar: Solo medicion en posicion X-Y-Z', fontsize=20)
plt.plot(t, np.asarray(mediciones)[:,0], label='Mediciones', color='b',linewidth=0.5)
plt.plot(t, np.asarray(predicciones)[:,0], label='Prediccion', color='y', linewidth=0.5)
plt.plot(t, np.asarray(estimaciones)[:,0], label='Estimacion', color='r', linewidth=0.5)
plt.xlabel('Tiempo (s)', fontsize=20)
plt.ylabel('Posicion X (m)', fontsize=20)
plt.legend()
plt.show()

# %%
#grafico sobre el eje y
t = np.arange(0, 351, h_tiempo_muestreo)
fig = plt.figure()
fig.suptitle('TP Kalman con 3 grados de libertar: Solo medicion en posicion X-Y-Z', fontsize=20)
plt.plot(t, np.asarray(mediciones)[:,1], label='Mediciones', color='b',linewidth=0.5)
plt.plot(t, np.asarray(predicciones)[:,1], label='Prediccion', color='y', linewidth=0.5)
plt.plot(t, np.asarray(estimaciones)[:,1], label='Estimacion', color='r', linewidth=0.5)
plt.xlabel('Tiempo (s)', fontsize=20)
plt.ylabel('Posicion Y (m)', fontsize=20)
plt.legend()
plt.show()

# %%
#grafico sobre el eje z
t = np.arange(0, 351, h_tiempo_muestreo)
fig = plt.figure()
fig.suptitle('TP Kalman con 3 grados de libertar: Solo medicion en posicion X-Y-Z', fontsize=20)
plt.plot(t, np.asarray(mediciones)[:,2], label='Mediciones', color='b',linewidth=0.5)
plt.plot(t, np.asarray(predicciones)[:,2], label='Prediccion', color='y', linewidth=0.5)
plt.plot(t, np.asarray(estimaciones)[:,2], label='Estimacion', color='r', linewidth=0.5)
plt.xlabel('Tiempo (s)', fontsize=20)
plt.ylabel('Posicion Z (m)', fontsize=20)
plt.legend()
plt.show()

# %%
#grafico los 3 componentes
fig = plt.figure(figsize=(10,8), dpi= 150)
ax = fig.gca(projection='3d')
ax.plot( np.asarray(estimaciones)[:,0],  np.asarray(estimaciones)[:,1], np.asarray(estimaciones)[:,2], label='valor estimado')
ax.plot(np.asarray(mediciones)[:,0], np.asarray(mediciones)[:,1], np.asarray(mediciones)[:,2], label='valor observado')
#ax.plot(np.asarray(predicciones)[:,0], np.asarray(predicciones)[:,1], np.asarray(predicciones)[:,2], label='valor predicto')
ax.legend()
plt.show()

# %%
#grafico los parametros de kalman para la vel y la pos. Es interesante que si es mas grande el ruido de velocidad el 
#salto inicial es mucho mas grande.
t = np.arange(0, 351, h_tiempo_muestreo)
fig = plt.figure()
fig.suptitle('TP Kalman valores', fontsize=20)
plt.plot(t, np.asarray(kalmanValores)[:,5,5], label='Valores de Kalman Vel Z', color='b',linewidth=0.5)
plt.plot(t, np.asarray(kalmanValores)[:,2,2], label='Valores de Kalman Pos Z', color='y',linewidth=0.5)
plt.xlabel('Tiempo (s)', fontsize=20)
plt.ylabel('Valores K', fontsize=20)
plt.legend()
plt.show()

# %%
#Vemos que al tener un dato de velocidad mejora mucho la estimacion de posicion.
#vemos que el ruido de velocidad si tiene mucha varianza arranca con valores muy grandes.
